# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as ss
import matplotlib
import random as rand
from matplotlib import pyplot as plt
from itertools import product
import itertools
import time
import re
import csv
from hurst import compute_Hc
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.linear_model import LinearRegression
from scipy.stats import boxcox
import tqdm

# %matplotlib inline

# %%
plt.rcParams["axes.labelsize"] = 16. 
plt.rcParams["xtick.labelsize"] = 14. 
plt.rcParams["ytick.labelsize"] = 14. 
plt.rcParams["legend.fontsize"] = 12. 
plt.rcParams["figure.figsize"] = [17., 8.]

# %% [markdown]
# # Так выглядят данные в случае отсутствия noise_traders

# %%
data = pd.read_csv('data/without_noise_traders.csv')

# %%
plt.plot(data['price'])
plt.title('data')
plt.show()

# %% [markdown]
# ------
# ## Так выглядят данные только с noise_traders

# %%
data_noise = pd.read_csv('data/only_noise_traders.csv')

# %%
plt.plot(data_noise['price'])
plt.title('data')
plt.show()

# %% [markdown]
# Что странно, тут то они могут и падать....
#
# -----
# ### Возьсём данные с минимумом noise_traders

# %%
data_min_noise = pd.read_csv('data/min_noise_traders.csv')

# %%
plt.plot(data_min_noise['price'])
plt.title('data')
plt.show()

# %% [markdown]
# -----
#
# Убрали market makers and liquidity consumers

# %%
data_var = pd.read_csv('data/first_var.csv')

# %%
plt.plot(data_var['price'])
plt.title('data')
plt.show()

# %% [markdown]
# -----
# Данные без market makers

# %%
data_mm = pd.read_csv('data/without_mm.csv')

# %%
plt.plot(data_mm['price'])
plt.title('data')
plt.show()

# %% [markdown]
# -----
# Данные без liquidity consumers

# %%
data_lc = pd.read_csv('data/without_lc.csv')

# %%
plt.plot(data_lc['price'])
plt.title('data')
plt.show()

# %%
plt.plot(data_lc['price'].pct_change())
plt.title('returns')
plt.show()

plt.plot(data_lc['price'].diff(1))
plt.title('differentiated')
plt.show()

# %% [markdown]
# ------

# %%
data_smth = pd.read_csv('data/smth.csv')

# %%
plt.plot(data_smth['price'])
plt.show()

# %% [markdown]
# ------
# We've improved our trend!

# %%
data_improved = pd.read_csv('data/improved_data.csv')

# %%
plt.plot(data_improved['price'][20:])
plt.show()
